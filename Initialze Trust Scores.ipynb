# %%
# %sql
-- Below statement assumes the default catalog is named 'workspace'
CREATE SCHEMA workspace.trustmodel;

# %%
# %sql
CREATE TABLE workspace.trustmodel.trust_scores (
    catalogName STRING,
    schemaName STRING,
    tableName STRING,
    hasComments BOOLEAN,
    allColumnsHaveComments BOOLEAN,
    hasHumanOwner BOOLEAN,
    weeksInProduction INT,
-- TODO: rename trust_score to trustScore
    trust_score INT
);
